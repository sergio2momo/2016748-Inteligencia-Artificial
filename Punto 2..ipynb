# %% [markdown]
# Escriba una clase iterable que tenga la siguiente funcionalidad:
# 1. Al instanciar un objeto, lee el archivo de datos y lo coloca en un dataframe interno en la clase.
# 2. Cada vez que se le pidan datos, debe regresar los dos siguientes datos.
# 3. Imprima "error" si los datos se han agotado.

# %%
#Importar librerías:

import pandas as pd

# %%
#Construir la clase:

class ClassOne:
    def __init__(self, file_path):
        self.data = pd.read_csv(file_path)
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.index >= len(self.data):
            raise StopIteration("error")
        else:
            row1, row2 = self.data.iloc[self.index], self.data.iloc[self.index+1]
            self.index += 2
            return row1, row2

# %%
#Probar la clase:

iris_iterator = ClassOne("iris.csv")
for _ in range(82):
    try:
        data = next(iris_iterator)
        print(data)
    except StopIteration as e:
        print(e)
        break
# Out:
# (sepal.length       5.1
# sepal.width        3.5
# petal.length       1.4
# petal.width        0.2
# variety         Setosa
# Name: 0, dtype: object, sepal.length       4.9
# sepal.width        3.0
# petal.length       1.4
# petal.width        0.2
# variety         Setosa
# Name: 1, dtype: object)
# (sepal.length       4.7
# sepal.width        3.2
# petal.length       1.3
# petal.width        0.2
# variety         Setosa
# Name: 2, dtype: object, sepal.length       4.6
# sepal.width        3.1
# petal.length       1.5
# petal.width        0.2
# variety         Setosa
# Name: 3, dtype: object)
# (sepal.length       5.0
# sepal.width        3.6
# petal.length       1.4
# petal.width        0.2
# variety         Setosa
# Name: 4, dtype: object, sepal.length       5.4
# sepal.width        3.9
# petal.length       1.7
# petal.width        0.4
# variety         Setosa
# Name: 5, dtype: object)
# (sepal.length       4.6
# sepal.width        3.4
# petal.length       1.4
# ...

# %%
for row in ClassOne("iris.csv"):
    print(row)
# Out:
# (sepal.length       5.1
# sepal.width        3.5
# petal.length       1.4
# petal.width        0.2
# variety         Setosa
# Name: 0, dtype: object, sepal.length       4.9
# sepal.width        3.0
# petal.length       1.4
# petal.width        0.2
# variety         Setosa
# Name: 1, dtype: object)
# (sepal.length       4.7
# sepal.width        3.2
# petal.length       1.3
# petal.width        0.2
# variety         Setosa
# Name: 2, dtype: object, sepal.length       4.6
# sepal.width        3.1
# petal.length       1.5
# petal.width        0.2
# variety         Setosa
# Name: 3, dtype: object)
# (sepal.length       5.0
# sepal.width        3.6
# petal.length       1.4
# petal.width        0.2
# variety         Setosa
# Name: 4, dtype: object, sepal.length       5.4
# sepal.width        3.9
# petal.length       1.7
# petal.width        0.4
# variety         Setosa
# Name: 5, dtype: object)
# (sepal.length       4.6
# sepal.width        3.4
# petal.length       1.4
# ...
